# %%
## Importing packages

# This R environment comes with all of CRAN and many other helpful packages preinstalled.
# You can see which packages are installed by checking out the kaggle/rstats docker image: 
# https://github.com/kaggle/docker-rstats

library(tidyverse) # metapackage with lots of helpful functions

## Running code

# In a notebook, you can run a single code cell by clicking in the cell and then hitting 
# the blue arrow to the left, or by clicking in the cell and pressing Shift+Enter. In a script, 
# you can run code by highlighting the code you want to run and then clicking the blue arrow
# at the bottom of this window.

## Reading in files

# You can access files from datasets you've added to this kernel in the "../input/" directory.
# You can see the files added to this kernel by running the code below. 

list.files(path = "../input")

## Saving data

# If you save any files or images, these will be put in the "output" directory. You 
# can see the output directory by committing and running your kernel (using the 
# Commit & Run button) and then checking out the compiled version of your kernel.
# Out:
# [1] "netflix-shows"

# %%
library('data.table')
data <- fread("../input/netflix-shows/netflix_titles_nov_2019.csv")

# %%
str(data)
# Out:
# Classes ‘data.table’ and 'data.frame':	5837 obs. of  12 variables:
#  $ show_id     : int  81193313 81197050 81213894 81082007 80213643 81172754 81120982 81227195 70205672 81172841 ...
#  $ title       : chr  "Chocolate" "Guatemala: Heart of the Mayan World" "The Zoya Factor" "Atlantics" ...
#  $ director    : chr  "" "Luis Ara, Ignacio Jaunsolo" "Abhishek Sharma" "Mati Diop" ...
#  $ cast        : chr  "Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang Bu-ja, Lee Jae-ryong, Min Jin-woong, Kim Won-hae, Yoo Teo" "Christian Morales" "Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, Sikander Kher, Angad Bedi, Koel Purie, Pooja Bhamrah, Manu Rishi Chadha" "Mama Sane, Amadou Mbow, Ibrahima Traore, Nicole Sougou, Amina Kane, Mariama Gassama, Coumba Dieng, Ibrahima Mba"| __truncated__ ...
#  $ country     : chr  "South Korea" "" "India" "France, Senegal, Belgium" ...
#  $ date_added  : chr  "November 30, 2019" "November 30, 2019" "November 30, 2019" "November 29, 2019" ...
# ...

# %%
summary(data)
# Out:
#     show_id            title             director             cast
#  Min.   :  269880   Length:5837        Length:5837        Length:5837
#  1st Qu.:80045203   Class :character   Class :character   Class :character
#  Median :80163533   Mode  :character   Mode  :character   Mode  :character
#  Mean   :77300790
#  3rd Qu.:80241876
#  Max.   :81227195
#    country           date_added         release_year     rating
#  Length:5837        Length:5837        Min.   :1925   Length:5837
#  Class :character   Class :character   1st Qu.:2013   Class :character
#  Mode  :character   Mode  :character   Median :2016   Mode  :character
#                                        Mean   :2014
#                                        3rd Qu.:2018
#                                        Max.   :2020
#    duration          listed_in         description            type
#  Length:5837        Length:5837        Length:5837        Length:5837
# ...

# %%
glimpse(data)
# Out:
# Observations: 5,837
# Variables: 12
# $ show_id      <int> 81193313, 81197050, 81213894, 81082007, 80213643, 811727…
# $ title        <chr> "Chocolate", "Guatemala: Heart of the Mayan World", "The…
# $ director     <chr> "", "Luis Ara, Ignacio Jaunsolo", "Abhishek Sharma", "Ma…
# $ cast         <chr> "Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang Bu-ja, Le…
# $ country      <chr> "South Korea", "", "India", "France, Senegal, Belgium", …
# $ date_added   <chr> "November 30, 2019", "November 30, 2019", "November 30, …
# $ release_year <int> 2019, 2019, 2019, 2019, 2019, 2018, 2019, 2016, 2019, 20…
# $ rating       <chr> "TV-14", "TV-G", "TV-14", "TV-14", "TV-Y", "TV-14", "TV-…
# $ duration     <chr> "1 Season", "67 min", "135 min", "106 min", "2 Seasons",…
# $ listed_in    <chr> "International TV Shows, Korean TV Shows, Romantic TV Sh…
# $ description  <chr> "Brought together by meaningful meals in the past and pr…
# ...

# %%
library(anytime)
data$date_added = anydate(data$date_added)
data$month_added = month(data$date_added)
data$year_added = year(data$date_added)

# %%
glimpse(data)
# Out:
# Observations: 5,837
# Variables: 14
# $ show_id      <int> 81193313, 81197050, 81213894, 81082007, 80213643, 811727…
# $ title        <chr> "Chocolate", "Guatemala: Heart of the Mayan World", "The…
# $ director     <chr> "", "Luis Ara, Ignacio Jaunsolo", "Abhishek Sharma", "Ma…
# $ cast         <chr> "Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang Bu-ja, Le…
# $ country      <chr> "South Korea", "", "India", "France, Senegal, Belgium", …
# $ date_added   <date> 2019-11-30, 2019-11-30, 2019-11-30, 2019-11-29, NA, 201…
# $ release_year <int> 2019, 2019, 2019, 2019, 2019, 2018, 2019, 2016, 2019, 20…
# $ rating       <chr> "TV-14", "TV-G", "TV-14", "TV-14", "TV-Y", "TV-14", "TV-…
# $ duration     <chr> "1 Season", "67 min", "135 min", "106 min", "2 Seasons",…
# $ listed_in    <chr> "International TV Shows, Korean TV Shows, Romantic TV Sh…
# $ description  <chr> "Brought together by meaningful meals in the past and pr…
# ...

# %%
library(skimr)
data %>%
skim()%>%
summary()
# Out:
# A skim object
#
# Number of Rows: 5837
# Number of Columns: 14
#
# Column type frequency
# character: 9
# Date: 1
# integer: 2
# numeric: 2

# %%
data2 <- data %>%
spread(key = type, value = duration)

# %%
glimpse(data2)
# Out:
# Observations: 5,837
# Variables: 14
# $ show_id      <int> 81193313, 81197050, 81213894, 81082007, 80213643, 811727…
# $ title        <chr> "Chocolate", "Guatemala: Heart of the Mayan World", "The…
# $ director     <chr> "", "Luis Ara, Ignacio Jaunsolo", "Abhishek Sharma", "Ma…
# $ cast         <chr> "Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang Bu-ja, Le…
# $ country      <chr> "South Korea", "", "India", "France, Senegal, Belgium", …
# $ date_added   <date> 2019-11-30, 2019-11-30, 2019-11-30, 2019-11-29, NA, 201…
# $ release_year <int> 2019, 2019, 2019, 2019, 2019, 2018, 2019, 2016, 2019, 20…
# $ rating       <chr> "TV-14", "TV-G", "TV-14", "TV-14", "TV-Y", "TV-14", "TV-…
# $ listed_in    <chr> "International TV Shows, Korean TV Shows, Romantic TV Sh…
# $ description  <chr> "Brought together by meaningful meals in the past and pr…
# $ month        <dbl> 11, 11, 11, 11, NA, 11, 11, 11, NA, 11, 11, 11, 11, 11, …
# ...

# %%
data2 %>%
mutate (Movie = parse_number(Movie), `TV Show` = parse_number(`TV Show`))
# Out:
#      show_id  title
# 1    81193313 Chocolate
# 2    81197050 Guatemala: Heart of the Mayan World
# 3    81213894 The Zoya Factor
# 4    81082007 Atlantics
# 5    80213643 Chip and Potato
# 6    81172754 Crazy people
# 7    81120982 I Lost My Body
# 8    81227195 Kalushi: The Story of Solomon Mahlangu
# 9    70205672 La Reina del Sur
# 10   81172841 Lagos Real Fake Life
# 11   81172899 Payday
# 12   81094391 Sugar Rush Christmas
# 13   81172908 The Accidental Spy
# 14   81152641 The Charming Stepmom
# 15   81172901 The Island
# 16   80990849 The Movies That Made Us
# 17   81033086 Holiday Rush
# 18   80156799 Levius
# 19   81161538 Lugar de Mulher
# 20   80997965 Merry Happy Whatever
# 21   81018979 Mythomaniac
# 22   60020826 The Score
# 23   81002391 Broken
# 24   70101696 Defiance
# 25   81194544 Evvarikee Cheppoddu
# 26   80995081 Little Singham: Mahabali
# 27   81177504 The Body Remembers When the World Broke Open
# 28   80175798 The Irishman
# ...
